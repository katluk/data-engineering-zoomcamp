# %%
import pandas as pd

# %%
df = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name='zone', con=engine))
# Out:
# CREATE TABLE zone (
# 	"LocationID" BIGINT,
# 	"Borough" TEXT,
# 	"Zone" TEXT,
# 	service_zone TEXT
# )

# %%
df.to_sql(name='zone', con=engine, if_exists='replace')
# Out:
# 265

# %%
query = """SELECT 
  column_name, 
  data_type, 
  character_maximum_length, 
  is_nullable, 
  column_default 
FROM 
  information_schema.columns 
WHERE 
  table_name = 'green_taxi_data';"""

pd.read_sql(query, con=engine)
# Out:
#               column_name                    data_type  \
# 0    congestion_surcharge             double precision
# 1                VendorID                       bigint
# 2    lpep_pickup_datetime  timestamp without time zone
# 3   lpep_dropoff_datetime  timestamp without time zone
# 4                   index                       bigint
# 5              RatecodeID                       bigint
# 6            PULocationID                       bigint
# 7            DOLocationID                       bigint
# 8         passenger_count                       bigint
# 9           trip_distance             double precision
# 10            fare_amount             double precision
# 11                  extra             double precision
# 12                mta_tax             double precision
# 13             tip_amount             double precision
# 14           tolls_amount             double precision
# 15              ehail_fee             double precision
# 16  improvement_surcharge             double precision
# 17           total_amount             double precision
# 18           payment_type                       bigint
# 19              trip_type                       bigint
# 20     store_and_fwd_flag                         text
#
#    character_maximum_length is_nullable column_default
# 0                      None         YES           None
# 1                      None         YES           None
# 2                      None         YES           None
# 3                      None         YES           None
# 4                      None         YES           None
# 5                      None         YES           None
# 6                      None         YES           None
# 7                      None         YES           None
# 8                      None         YES           None
# 9                      None         YES           None
# 10                     None         YES           None
# 11                     None         YES           None
# 12                     None         YES           None
# 13                     None         YES           None
# 14                     None         YES           None
# 15                     None         YES           None
# 16                     None         YES           None
# 17                     None         YES           None
# 18                     None         YES           None
# 19                     None         YES           None
# 20                     None         YES           None
